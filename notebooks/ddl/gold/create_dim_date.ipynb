-- %%
DROP TABLE IF EXISTS airline_catalog.gold.dim_date;
CREATE TABLE IF NOT EXISTS airline_catalog.gold.dim_date
(
    date_id DATE,
    year INT,
    month INT,
    day INT,
    day_of_week INT,
    is_weekend BOOLEAN,
    _created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP()
)
USING DELTA
TBLPROPERTIES('delta.feature.allowColumnDefaults' = 'supported');
