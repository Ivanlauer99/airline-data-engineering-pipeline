-- %%
DROP TABLE IF EXISTS airline_catalog.lookups.airport_lookup;
CREATE TABLE airline_catalog.lookups.airport_lookup AS
SELECT code, description
FROM read_files(
  '/Volumes/airline_catalog/landing/lookups/L_AIRPORT.csv',
  format => 'csv',
  header => true
);

-- %%
FROM read_files(
  '/Volumes/airline_catalog/landing/lookups/L_AIRPORT.csv',
  format => 'csv',
  header => true
);

-- %%
select * from airline_catalog.lookups.airport_lookup
