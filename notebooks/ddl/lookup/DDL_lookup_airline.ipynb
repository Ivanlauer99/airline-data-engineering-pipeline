-- %%
DROP TABLE IF EXISTS airline_catalog.lookups.airline_lookup;
CREATE TABLE airline_catalog.lookups.airline_lookup AS
SELECT code, description
FROM read_files(
  '/Volumes/airline_catalog/landing/lookups/L_UNIQUE_CARRIERS.csv',
  format => 'csv',
  header => true
);

-- %%
select * from airline_catalog.lookups.airline_lookup
