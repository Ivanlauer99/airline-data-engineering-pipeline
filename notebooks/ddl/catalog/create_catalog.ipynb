-- %%
%sql
-- ============================================================
--Creacion del catalogo
-- ============================================================
create catalog if not exists airline_catalog;
