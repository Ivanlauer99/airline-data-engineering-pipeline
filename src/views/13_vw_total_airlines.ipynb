# %%
# %sql
create or replace view airline_catalog.semantic.vw_total_airlines as
select count(distinct airline_id) as total_airlines from airline_catalog.gold.dim_airline

# %%
# %sql
SELECT * FROM airline_catalog.semantic.vw_total_airlines
